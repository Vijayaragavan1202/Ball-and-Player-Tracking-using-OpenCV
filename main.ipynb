# %% [markdown]
# ## 1. Import required libraries and the CSV logger

# %%
from ultralytics import YOLO
import cv2
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from scipy.optimize import linear_sum_assignment

# %%
import csv

class csv_gen:
    def __init__(self, csv_path):
        self.csv_file = open(csv_path, mode='w', newline='')
        self.csv_writer = csv.writer(self.csv_file)
        self.csv_writer.writerow(['frame', 'player_id', 'x_center', 'y_center'])
    
    def log_player(self, frame_idx, player_id, x_center, y_center):
        self.csv_writer.writerow([frame_idx, player_id, x_center, y_center])
    
    def close(self):
        self.csv_file.close()

# %% [markdown]
# ## 2. Initialize model, video, output writer, and tracking parameters

# %%
model_path = 'best.pt'
video_path = '15sec_input_720p.mp4'

model = YOLO(model_path)
cap = cv2.VideoCapture(video_path)

frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output_tracking.mp4', fourcc, fps, (frame_width, frame_height))

player_db = {}
next_player_id = 0
appearance_weight = 0.7
position_weight = 0.3
similarity_threshold = 0.65
frame_idx = 0

logger = csv_gen('player_positions.csv')

# %% [markdown]
# ## 3. Define helper functions for feature extraction and similarity computation

# %%
def extract_color_histogram(image, bins=(8, 8, 8)):
    if image.size == 0:
        return np.zeros(np.prod(bins))
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist = cv2.calcHist([hsv], [0, 1, 2], None, bins, [0, 180, 0, 256, 0, 256])
    cv2.normalize(hist, hist)
    return hist.flatten()

def compute_similarity(feat1, feat2):
    if feat1 is None or feat2 is None:
        return 0
    feat1 = feat1.reshape(1, -1)
    feat2 = feat2.reshape(1, -1)
    return cosine_similarity(feat1, feat2)[0][0]

def compute_position_similarity(center1, center2, frame_shape):
    diag = np.sqrt(frame_shape[0]**2 + frame_shape[1]**2)
    dist = np.linalg.norm(np.array(center1) - np.array(center2))
    return 1 - (dist / diag)

# %% [markdown]
# ## 4. Main tracking loop: detect, track, assign IDs, visualize, and log to CSV

# %%
while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)
    if frame_idx == 0:
        print("Class mapping:", results[0].names)

    detections = []
    for det in results[0].boxes:
        x1, y1, x2, y2 = map(int, det.xyxy[0])
        conf = float(det.conf[0])
        cls = int(det.cls[0])
        label = results[0].names[cls]
        cx, cy = int((x1 + x2) / 2), int((y1 + y2) / 2)
        if label == 'player' and conf > 0.4:
            crop = frame[y1:y2, x1:x2]
            features = extract_color_histogram(crop)
            detections.append({
                'bbox': (x1, y1, x2, y2),
                'features': features,
                'center': (cx, cy),
                'type': 'player',
                'assigned': False
            })
        elif label == 'ball' and conf > 0.4:
            detections.append({'bbox': (x1, y1, x2, y2), 'type': 'ball'})

    player_candidates = []
    candidate_ids = []
    candidate_centers = []
    for pid, pdata in player_db.items():
        if pdata['status'] == 'active':
            player_candidates.append(pdata['features'])
            candidate_ids.append(pid)
            candidate_centers.append(pdata['center'])

    det_features = [det['features'] for det in detections if det['type'] == 'player']
    det_centers = [det['center'] for det in detections if det['type'] == 'player']
    det_indices = [i for i, det in enumerate(detections) if det['type'] == 'player']

    if player_candidates and det_features:
        cost_matrix = np.ones((len(player_candidates), len(det_features)))
        for i, (feat_db, center_db) in enumerate(zip(player_candidates, candidate_centers)):
            for j, (feat_det, center_det) in enumerate(zip(det_features, det_centers)):
                app_sim = compute_similarity(feat_db, feat_det)
                pos_sim = compute_position_similarity(center_db, center_det, frame.shape)
                sim = appearance_weight * app_sim + position_weight * pos_sim
                cost_matrix[i, j] = 1 - sim
        row_ind, col_ind = linear_sum_assignment(cost_matrix)
        for r, c in zip(row_ind, col_ind):
            sim = 1 - cost_matrix[r, c]
            if sim >= similarity_threshold:
                pid = candidate_ids[r]
                det_idx = det_indices[c]
                detections[det_idx]['id'] = pid
                detections[det_idx]['assigned'] = True
                player_db[pid]['features'] = detections[det_idx]['features']
                player_db[pid]['center'] = detections[det_idx]['center']
                player_db[pid]['last_seen'] = frame_idx
                player_db[pid]['status'] = 'active'

    for i, det in enumerate(detections):
        if det['type'] == 'player' and not det.get('assigned', False):
            pid = next_player_id
            detections[i]['id'] = pid
            detections[i]['assigned'] = True
            player_db[pid] = {
                'features': det['features'],
                'center': det['center'],
                'last_seen': frame_idx,
                'status': 'active'
            }
            next_player_id += 1

    to_remove = []
    for pid, pdata in player_db.items():
        if pdata['status'] == 'active' and pdata['last_seen'] < frame_idx:
            pdata['status'] = 'lost'
        elif pdata['status'] == 'lost':
            to_remove.append(pid)
    for pid in to_remove:
        del player_db[pid]

    for det in detections:
        x1, y1, x2, y2 = det['bbox']
        if det['type'] == 'player':
            pid = det['id']
            color = (0, 255, 0) if player_db.get(pid, {}).get('status', '') == 'active' else (0, 165, 255)
            cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
            cv2.putText(frame, f'Player ID: {pid}', (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)
            logger.log_player(frame_idx, pid, int((x1 + x2) / 2), int((y1 + y2) / 2))
        elif det['type'] == 'ball':
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
            cv2.putText(frame, 'Ball', (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

    out.write(frame)
    cv2.imshow('Tracking', frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    frame_idx += 1

cap.release()
out.release()
logger.close()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 ball, 16 players, 2 referees, 1225.5ms
# Speed: 9.9ms preprocess, 1225.5ms inference, 15.9ms postprocess per image at shape (1, 3, 384, 640)
# Class mapping: {0: 'ball', 1: 'goalkeeper', 2: 'player', 3: 'referee'}
#
# 0: 384x640 18 players, 2 referees, 756.1ms
# Speed: 5.7ms preprocess, 756.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 649.6ms
# Speed: 1.8ms preprocess, 649.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 654.5ms
# Speed: 2.4ms preprocess, 654.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 694.5ms
# Speed: 2.2ms preprocess, 694.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 945.9ms
# Speed: 6.1ms preprocess, 945.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 709.6ms
# Speed: 1.9ms preprocess, 709.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 682.2ms
# Speed: 1.8ms preprocess, 682.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 647.6ms
# Speed: 2.0ms preprocess, 647.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 638.4ms
# Speed: 2.0ms preprocess, 638.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 719.4ms
# Speed: 1.9ms preprocess, 719.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 717.1ms
# Speed: 1.9ms preprocess, 717.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 721.0ms
# Speed: 1.6ms preprocess, 721.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 636.7ms
# Speed: 1.8ms preprocess, 636.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 636.2ms
# Speed: 1.8ms preprocess, 636.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 2 referees, 635.8ms
# Speed: 1.8ms preprocess, 635.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 662.2ms
# Speed: 1.7ms preprocess, 662.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 647.5ms
# Speed: 2.0ms preprocess, 647.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 668.2ms
# Speed: 1.7ms preprocess, 668.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 635.4ms
# Speed: 1.9ms preprocess, 635.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 634.1ms
# Speed: 2.0ms preprocess, 634.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 662.7ms
# Speed: 1.8ms preprocess, 662.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 692.5ms
# Speed: 1.7ms preprocess, 692.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 684.8ms
# Speed: 1.8ms preprocess, 684.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 648.9ms
# Speed: 1.9ms preprocess, 648.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 758.9ms
# Speed: 1.7ms preprocess, 758.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 712.5ms
# Speed: 1.8ms preprocess, 712.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 2 referees, 655.0ms
# Speed: 1.7ms preprocess, 655.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 2 referees, 765.8ms
# Speed: 1.7ms preprocess, 765.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 16 players, 2 referees, 668.2ms
# Speed: 1.7ms preprocess, 668.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 15 players, 2 referees, 743.3ms
# Speed: 1.8ms preprocess, 743.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 731.4ms
# Speed: 1.6ms preprocess, 731.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 679.6ms
# Speed: 1.7ms preprocess, 679.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 724.9ms
# Speed: 1.7ms preprocess, 724.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 727.2ms
# Speed: 2.0ms preprocess, 727.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 3 referees, 662.8ms
# Speed: 2.1ms preprocess, 662.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 727.7ms
# Speed: 1.8ms preprocess, 727.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1095.3ms
# Speed: 2.5ms preprocess, 1095.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 705.2ms
# Speed: 1.9ms preprocess, 705.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 719.5ms
# Speed: 1.9ms preprocess, 719.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 3 referees, 930.9ms
# Speed: 2.2ms preprocess, 930.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 929.3ms
# Speed: 1.9ms preprocess, 929.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 892.2ms
# Speed: 2.4ms preprocess, 892.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 979.9ms
# Speed: 2.1ms preprocess, 979.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 918.0ms
# Speed: 1.9ms preprocess, 918.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 950.6ms
# Speed: 1.8ms preprocess, 950.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 832.6ms
# Speed: 1.9ms preprocess, 832.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1096.3ms
# Speed: 2.0ms preprocess, 1096.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 762.3ms
# Speed: 1.9ms preprocess, 762.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 781.8ms
# Speed: 2.0ms preprocess, 781.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 724.2ms
# Speed: 1.6ms preprocess, 724.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 3 referees, 675.2ms
# Speed: 1.8ms preprocess, 675.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 3 referees, 720.4ms
# Speed: 1.8ms preprocess, 720.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 3 referees, 708.0ms
# Speed: 1.6ms preprocess, 708.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 4 referees, 762.4ms
# Speed: 2.0ms preprocess, 762.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 700.8ms
# Speed: 1.8ms preprocess, 700.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 736.9ms
# Speed: 2.0ms preprocess, 736.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 2 referees, 739.7ms
# Speed: 1.6ms preprocess, 739.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 651.2ms
# Speed: 1.9ms preprocess, 651.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 691.5ms
# Speed: 1.9ms preprocess, 691.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1008.7ms
# Speed: 2.0ms preprocess, 1008.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 1011.2ms
# Speed: 2.1ms preprocess, 1011.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 727.2ms
# Speed: 2.0ms preprocess, 727.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 948.4ms
# Speed: 1.7ms preprocess, 948.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 1217.7ms
# Speed: 2.2ms preprocess, 1217.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 4 referees, 822.7ms
# Speed: 1.7ms preprocess, 822.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 3 referees, 2218.4ms
# Speed: 279.7ms preprocess, 2218.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 4 referees, 1170.0ms
# Speed: 3.0ms preprocess, 1170.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 860.8ms
# Speed: 3.2ms preprocess, 860.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 989.5ms
# Speed: 2.0ms preprocess, 989.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 1007.5ms
# Speed: 1.7ms preprocess, 1007.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 898.8ms
# Speed: 4.1ms preprocess, 898.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 940.6ms
# Speed: 2.1ms preprocess, 940.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 940.7ms
# Speed: 2.3ms preprocess, 940.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 926.3ms
# Speed: 1.8ms preprocess, 926.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 744.9ms
# Speed: 2.0ms preprocess, 744.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 735.9ms
# Speed: 1.7ms preprocess, 735.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 858.1ms
# Speed: 1.8ms preprocess, 858.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 2 referees, 843.5ms
# Speed: 1.8ms preprocess, 843.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 787.0ms
# Speed: 1.7ms preprocess, 787.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 851.1ms
# Speed: 1.5ms preprocess, 851.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 2 referees, 911.1ms
# Speed: 1.8ms preprocess, 911.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 870.2ms
# Speed: 1.9ms preprocess, 870.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 797.8ms
# Speed: 2.0ms preprocess, 797.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 809.7ms
# Speed: 2.5ms preprocess, 809.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 2 referees, 799.9ms
# Speed: 2.0ms preprocess, 799.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 711.5ms
# Speed: 1.9ms preprocess, 711.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 675.7ms
# Speed: 1.9ms preprocess, 675.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 749.0ms
# Speed: 2.0ms preprocess, 749.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 851.3ms
# Speed: 1.6ms preprocess, 851.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 700.2ms
# Speed: 1.8ms preprocess, 700.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 3 referees, 899.2ms
# Speed: 1.8ms preprocess, 899.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 890.0ms
# Speed: 1.8ms preprocess, 890.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 708.9ms
# Speed: 1.9ms preprocess, 708.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 682.7ms
# Speed: 1.9ms preprocess, 682.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 652.3ms
# Speed: 1.7ms preprocess, 652.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 658.2ms
# Speed: 1.8ms preprocess, 658.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 2 referees, 838.9ms
# Speed: 1.7ms preprocess, 838.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 3 referees, 995.0ms
# Speed: 3.6ms preprocess, 995.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 799.9ms
# Speed: 1.6ms preprocess, 799.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 857.3ms
# Speed: 1.9ms preprocess, 857.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 784.5ms
# Speed: 2.5ms preprocess, 784.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 905.5ms
# Speed: 2.0ms preprocess, 905.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 2 referees, 1049.6ms
# Speed: 3.0ms preprocess, 1049.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 1026.8ms
# Speed: 3.4ms preprocess, 1026.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 2 referees, 902.1ms
# Speed: 1.9ms preprocess, 902.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 19 players, 2 referees, 915.3ms
# Speed: 2.6ms preprocess, 915.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 774.8ms
# Speed: 1.8ms preprocess, 774.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 816.2ms
# Speed: 1.9ms preprocess, 816.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 937.9ms
# Speed: 2.0ms preprocess, 937.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 17 players, 923.7ms
# Speed: 1.7ms preprocess, 923.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 17 players, 1 referee, 776.4ms
# Speed: 1.9ms preprocess, 776.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 1 referee, 758.6ms
# Speed: 1.9ms preprocess, 758.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 2 referees, 730.7ms
# Speed: 2.3ms preprocess, 730.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 821.9ms
# Speed: 1.8ms preprocess, 821.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 911.0ms
# Speed: 1.8ms preprocess, 911.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 798.2ms
# Speed: 1.8ms preprocess, 798.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 781.4ms
# Speed: 2.0ms preprocess, 781.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 1 referee, 794.1ms
# Speed: 2.1ms preprocess, 794.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1044.2ms
# Speed: 2.3ms preprocess, 1044.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 1112.7ms
# Speed: 2.4ms preprocess, 1112.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1042.2ms
# Speed: 2.0ms preprocess, 1042.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 872.4ms
# Speed: 3.1ms preprocess, 872.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 928.4ms
# Speed: 3.4ms preprocess, 928.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 1007.3ms
# Speed: 2.7ms preprocess, 1007.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 2 referees, 879.2ms
# Speed: 2.8ms preprocess, 879.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 926.8ms
# Speed: 2.0ms preprocess, 926.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 743.5ms
# Speed: 2.6ms preprocess, 743.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 825.9ms
# Speed: 1.9ms preprocess, 825.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 941.6ms
# Speed: 1.9ms preprocess, 941.6ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1073.7ms
# Speed: 2.6ms preprocess, 1073.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1108.0ms
# Speed: 2.4ms preprocess, 1108.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 18 players, 1 referee, 1141.4ms
# Speed: 2.6ms preprocess, 1141.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 1159.5ms
# Speed: 1.9ms preprocess, 1159.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 993.8ms
# Speed: 2.8ms preprocess, 993.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1004.6ms
# Speed: 2.4ms preprocess, 1004.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 16 players, 1 referee, 910.9ms
# Speed: 2.0ms preprocess, 910.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 772.4ms
# Speed: 1.9ms preprocess, 772.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 18 players, 1 referee, 1078.0ms
# Speed: 1.9ms preprocess, 1078.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 754.9ms
# Speed: 1.9ms preprocess, 754.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 1053.2ms
# Speed: 1.9ms preprocess, 1053.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 811.6ms
# Speed: 4.1ms preprocess, 811.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 900.5ms
# Speed: 2.2ms preprocess, 900.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 796.9ms
# Speed: 1.8ms preprocess, 796.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 755.5ms
# Speed: 1.8ms preprocess, 755.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 2 referees, 843.1ms
# Speed: 3.1ms preprocess, 843.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1 referee, 661.8ms
# Speed: 1.5ms preprocess, 661.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 719.3ms
# Speed: 1.8ms preprocess, 719.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 733.2ms
# Speed: 1.8ms preprocess, 733.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 939.0ms
# Speed: 2.0ms preprocess, 939.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 818.3ms
# Speed: 1.9ms preprocess, 818.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 660.1ms
# Speed: 1.8ms preprocess, 660.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 661.5ms
# Speed: 1.8ms preprocess, 661.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1 referee, 860.2ms
# Speed: 2.0ms preprocess, 860.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1 referee, 653.3ms
# Speed: 1.7ms preprocess, 653.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 850.1ms
# Speed: 1.7ms preprocess, 850.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 935.9ms
# Speed: 1.7ms preprocess, 935.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 686.6ms
# Speed: 2.8ms preprocess, 686.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 816.5ms
# Speed: 2.1ms preprocess, 816.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 850.0ms
# Speed: 1.9ms preprocess, 850.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 794.2ms
# Speed: 1.6ms preprocess, 794.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 669.8ms
# Speed: 1.8ms preprocess, 669.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 667.0ms
# Speed: 1.8ms preprocess, 667.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 709.5ms
# Speed: 2.1ms preprocess, 709.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 768.4ms
# Speed: 1.8ms preprocess, 768.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 880.0ms
# Speed: 1.8ms preprocess, 880.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 843.1ms
# Speed: 2.0ms preprocess, 843.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 985.9ms
# Speed: 2.2ms preprocess, 985.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 712.5ms
# Speed: 1.9ms preprocess, 712.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 894.3ms
# Speed: 1.8ms preprocess, 894.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1 referee, 904.6ms
# Speed: 2.3ms preprocess, 904.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 725.7ms
# Speed: 1.9ms preprocess, 725.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1221.4ms
# Speed: 1.8ms preprocess, 1221.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 900.2ms
# Speed: 1.8ms preprocess, 900.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1033.6ms
# Speed: 2.4ms preprocess, 1033.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 949.0ms
# Speed: 3.6ms preprocess, 949.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1066.8ms
# Speed: 2.5ms preprocess, 1066.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1042.0ms
# Speed: 3.8ms preprocess, 1042.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 1 referee, 1338.9ms
# Speed: 3.0ms preprocess, 1338.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 11 players, 1 referee, 1224.7ms
# Speed: 2.5ms preprocess, 1224.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 1 referee, 1151.9ms
# Speed: 2.1ms preprocess, 1151.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 878.8ms
# Speed: 1.7ms preprocess, 878.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 1011.7ms
# Speed: 16.0ms preprocess, 1011.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1 referee, 799.5ms
# Speed: 1.9ms preprocess, 799.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 842.8ms
# Speed: 2.1ms preprocess, 842.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 958.9ms
# Speed: 1.8ms preprocess, 958.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 967.1ms
# Speed: 5.8ms preprocess, 967.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 970.2ms
# Speed: 2.7ms preprocess, 970.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1 referee, 1109.5ms
# Speed: 1.9ms preprocess, 1109.5ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1 referee, 848.8ms
# Speed: 1.9ms preprocess, 848.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 1 referee, 815.5ms
# Speed: 1.9ms preprocess, 815.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 946.2ms
# Speed: 1.9ms preprocess, 946.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 843.8ms
# Speed: 4.7ms preprocess, 843.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 14 players, 799.0ms
# Speed: 1.9ms preprocess, 799.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 852.9ms
# Speed: 8.8ms preprocess, 852.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 938.5ms
# Speed: 1.9ms preprocess, 938.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 952.0ms
# Speed: 2.1ms preprocess, 952.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 978.2ms
# Speed: 2.1ms preprocess, 978.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 833.9ms
# Speed: 1.9ms preprocess, 833.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 885.0ms
# Speed: 2.2ms preprocess, 885.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 1042.9ms
# Speed: 2.0ms preprocess, 1042.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 845.3ms
# Speed: 1.9ms preprocess, 845.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 765.8ms
# Speed: 1.9ms preprocess, 765.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 900.2ms
# Speed: 1.8ms preprocess, 900.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 13 players, 1292.8ms
# Speed: 2.2ms preprocess, 1292.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 1104.9ms
# Speed: 2.4ms preprocess, 1104.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 969.5ms
# Speed: 2.8ms preprocess, 969.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 779.9ms
# Speed: 1.9ms preprocess, 779.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 1013.8ms
# Speed: 2.0ms preprocess, 1013.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 13 players, 1200.7ms
# Speed: 2.1ms preprocess, 1200.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 777.2ms
# Speed: 2.3ms preprocess, 777.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 781.9ms
# Speed: 1.9ms preprocess, 781.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 928.7ms
# Speed: 1.9ms preprocess, 928.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 736.0ms
# Speed: 2.2ms preprocess, 736.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 10 players, 702.6ms
# Speed: 1.8ms preprocess, 702.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 777.3ms
# Speed: 1.7ms preprocess, 777.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 15 players, 783.3ms
# Speed: 2.3ms preprocess, 783.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 849.3ms
# Speed: 1.9ms preprocess, 849.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 903.2ms
# Speed: 2.0ms preprocess, 903.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 811.0ms
# Speed: 1.9ms preprocess, 811.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 799.8ms
# Speed: 2.0ms preprocess, 799.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 949.6ms
# Speed: 2.0ms preprocess, 949.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 1028.2ms
# Speed: 3.3ms preprocess, 1028.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 863.5ms
# Speed: 1.6ms preprocess, 863.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 990.4ms
# Speed: 2.7ms preprocess, 990.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 970.7ms
# Speed: 2.0ms preprocess, 970.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 9 players, 1041.5ms
# Speed: 2.2ms preprocess, 1041.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1239.9ms
# Speed: 5.5ms preprocess, 1239.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1091.3ms
# Speed: 4.1ms preprocess, 1091.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 11 players, 2582.0ms
# Speed: 2.1ms preprocess, 2582.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 1385.8ms
# Speed: 2.7ms preprocess, 1385.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 12 players, 1817.3ms
# Speed: 10.2ms preprocess, 1817.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 1007.6ms
# Speed: 2.3ms preprocess, 1007.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 balls, 8 players, 3056.6ms
# Speed: 2.7ms preprocess, 3056.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1350.5ms
# Speed: 2.0ms preprocess, 1350.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 900.0ms
# Speed: 1.9ms preprocess, 900.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 824.0ms
# Speed: 4.4ms preprocess, 824.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 803.5ms
# Speed: 2.0ms preprocess, 803.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 756.2ms
# Speed: 1.9ms preprocess, 756.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 1326.0ms
# Speed: 1.8ms preprocess, 1326.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 8 players, 1350.6ms
# Speed: 2.9ms preprocess, 1350.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 735.8ms
# Speed: 1.8ms preprocess, 735.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 7 players, 880.7ms
# Speed: 2.3ms preprocess, 880.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 742.3ms
# Speed: 1.8ms preprocess, 742.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 688.5ms
# Speed: 1.8ms preprocess, 688.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 680.9ms
# Speed: 1.8ms preprocess, 680.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 756.5ms
# Speed: 1.8ms preprocess, 756.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 752.7ms
# Speed: 1.6ms preprocess, 752.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 11 players, 728.0ms
# Speed: 1.6ms preprocess, 728.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 10 players, 804.4ms
# Speed: 1.8ms preprocess, 804.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 balls, 1 goalkeeper, 9 players, 701.9ms
# Speed: 2.0ms preprocess, 701.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 9 players, 736.6ms
# Speed: 1.7ms preprocess, 736.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 738.9ms
# Speed: 1.7ms preprocess, 738.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 736.7ms
# Speed: 1.6ms preprocess, 736.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 674.9ms
# Speed: 1.8ms preprocess, 674.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 742.2ms
# Speed: 3.9ms preprocess, 742.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 743.7ms
# Speed: 2.0ms preprocess, 743.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 696.0ms
# Speed: 2.3ms preprocess, 696.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 10 players, 746.6ms
# Speed: 2.0ms preprocess, 746.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 978.1ms
# Speed: 2.0ms preprocess, 978.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 848.3ms
# Speed: 1.7ms preprocess, 848.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 867.5ms
# Speed: 1.6ms preprocess, 867.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1004.3ms
# Speed: 2.0ms preprocess, 1004.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1066.9ms
# Speed: 2.0ms preprocess, 1066.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 1302.0ms
# Speed: 3.3ms preprocess, 1302.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 1027.0ms
# Speed: 1.8ms preprocess, 1027.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1064.0ms
# Speed: 2.1ms preprocess, 1064.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1015.6ms
# Speed: 2.1ms preprocess, 1015.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 924.0ms
# Speed: 2.1ms preprocess, 924.0ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 11 players, 1254.1ms
# Speed: 2.2ms preprocess, 1254.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 8 players, 1250.2ms
# Speed: 3.8ms preprocess, 1250.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 979.1ms
# Speed: 2.5ms preprocess, 979.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 944.7ms
# Speed: 3.1ms preprocess, 944.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 866.1ms
# Speed: 2.2ms preprocess, 866.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 1012.2ms
# Speed: 2.0ms preprocess, 1012.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 1151.3ms
# Speed: 3.1ms preprocess, 1151.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 players, 1316.6ms
# Speed: 4.0ms preprocess, 1316.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 845.5ms
# Speed: 2.1ms preprocess, 845.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 10 players, 792.1ms
# Speed: 1.8ms preprocess, 792.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 731.2ms
# Speed: 2.0ms preprocess, 731.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 735.7ms
# Speed: 1.9ms preprocess, 735.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 762.5ms
# Speed: 1.9ms preprocess, 762.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 859.9ms
# Speed: 2.2ms preprocess, 859.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 772.1ms
# Speed: 1.8ms preprocess, 772.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 708.6ms
# Speed: 1.9ms preprocess, 708.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 12 players, 666.8ms
# Speed: 1.7ms preprocess, 666.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 730.0ms
# Speed: 2.0ms preprocess, 730.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 754.8ms
# Speed: 1.8ms preprocess, 754.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 688.9ms
# Speed: 1.9ms preprocess, 688.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 679.0ms
# Speed: 1.9ms preprocess, 679.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 9 players, 667.4ms
# Speed: 1.8ms preprocess, 667.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 794.9ms
# Speed: 1.8ms preprocess, 794.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 743.5ms
# Speed: 1.9ms preprocess, 743.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 801.9ms
# Speed: 2.0ms preprocess, 801.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 871.3ms
# Speed: 2.1ms preprocess, 871.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 18 players, 697.2ms
# Speed: 2.0ms preprocess, 697.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 812.1ms
# Speed: 2.2ms preprocess, 812.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 745.9ms
# Speed: 2.3ms preprocess, 745.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 688.1ms
# Speed: 2.1ms preprocess, 688.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 664.7ms
# Speed: 1.8ms preprocess, 664.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 668.5ms
# Speed: 1.6ms preprocess, 668.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 713.6ms
# Speed: 1.8ms preprocess, 713.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 702.7ms
# Speed: 1.8ms preprocess, 702.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 889.7ms
# Speed: 2.0ms preprocess, 889.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 671.2ms
# Speed: 1.8ms preprocess, 671.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 746.7ms
# Speed: 1.9ms preprocess, 746.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 18 players, 706.6ms
# Speed: 2.4ms preprocess, 706.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 784.8ms
# Speed: 1.9ms preprocess, 784.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1116.5ms
# Speed: 2.9ms preprocess, 1116.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 17 players, 673.7ms
# Speed: 1.6ms preprocess, 673.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 15 players, 843.7ms
# Speed: 1.8ms preprocess, 843.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 19 players, 681.7ms
# Speed: 1.7ms preprocess, 681.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 15 players, 866.3ms
# Speed: 1.7ms preprocess, 866.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 724.1ms
# Speed: 1.9ms preprocess, 724.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 13 players, 930.9ms
# Speed: 1.8ms preprocess, 930.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 16 players, 751.0ms
# Speed: 2.0ms preprocess, 751.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 12 players, 758.1ms
# Speed: 1.8ms preprocess, 758.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 14 players, 739.5ms
# Speed: 1.9ms preprocess, 739.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 16 players, 935.0ms
# Speed: 2.0ms preprocess, 935.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 1 goalkeeper, 13 players, 725.3ms
# Speed: 2.7ms preprocess, 725.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 745.9ms
# Speed: 1.7ms preprocess, 745.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 709.1ms
# Speed: 1.8ms preprocess, 709.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 770.4ms
# Speed: 1.6ms preprocess, 770.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 798.4ms
# Speed: 2.0ms preprocess, 798.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 727.4ms
# Speed: 1.8ms preprocess, 727.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 661.5ms
# Speed: 1.6ms preprocess, 661.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 14 players, 921.0ms
# Speed: 1.7ms preprocess, 921.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 17 players, 924.3ms
# Speed: 2.0ms preprocess, 924.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 11 players, 744.7ms
# Speed: 2.0ms preprocess, 744.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 665.0ms
# Speed: 1.8ms preprocess, 665.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 658.7ms
# Speed: 1.7ms preprocess, 658.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 704.9ms
# Speed: 1.8ms preprocess, 704.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 734.5ms
# Speed: 1.9ms preprocess, 734.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 667.3ms
# Speed: 2.0ms preprocess, 667.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 1076.9ms
# Speed: 2.1ms preprocess, 1076.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 players, 986.8ms
# Speed: 2.4ms preprocess, 986.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 9 players, 756.2ms
# Speed: 2.1ms preprocess, 756.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 11 players, 698.1ms
# Speed: 1.7ms preprocess, 698.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 players, 1109.3ms
# Speed: 1.9ms preprocess, 1109.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 925.0ms
# Speed: 11.5ms preprocess, 925.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 842.3ms
# Speed: 2.2ms preprocess, 842.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 717.6ms
# Speed: 1.7ms preprocess, 717.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 975.2ms
# Speed: 2.1ms preprocess, 975.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 814.4ms
# Speed: 1.8ms preprocess, 814.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 888.8ms
# Speed: 4.3ms preprocess, 888.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 694.2ms
# Speed: 1.8ms preprocess, 694.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 681.9ms
# Speed: 1.9ms preprocess, 681.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 747.1ms
# Speed: 1.7ms preprocess, 747.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 868.3ms
# Speed: 2.7ms preprocess, 868.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 770.1ms
# Speed: 1.9ms preprocess, 770.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 750.9ms
# Speed: 1.9ms preprocess, 750.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 728.2ms
# Speed: 1.7ms preprocess, 728.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 789.2ms
# Speed: 1.9ms preprocess, 789.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 957.5ms
# Speed: 1.8ms preprocess, 957.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 16 players, 1172.0ms
# Speed: 2.6ms preprocess, 1172.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 players, 703.5ms
# Speed: 1.9ms preprocess, 703.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 814.6ms
# Speed: 2.2ms preprocess, 814.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 792.8ms
# Speed: 2.0ms preprocess, 792.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 884.1ms
# Speed: 2.0ms preprocess, 884.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 691.2ms
# Speed: 1.8ms preprocess, 691.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 792.0ms
# Speed: 1.8ms preprocess, 792.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 785.8ms
# Speed: 1.9ms preprocess, 785.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 659.7ms
# Speed: 1.5ms preprocess, 659.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 878.8ms
# Speed: 1.6ms preprocess, 878.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 749.9ms
# Speed: 2.0ms preprocess, 749.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 680.6ms
# Speed: 1.9ms preprocess, 680.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 13 players, 745.6ms
# Speed: 1.6ms preprocess, 745.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 14 players, 661.3ms
# Speed: 1.6ms preprocess, 661.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 873.0ms
# Speed: 1.7ms preprocess, 873.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 15 players, 793.0ms
# Speed: 1.7ms preprocess, 793.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 12 players, 671.8ms
# Speed: 1.8ms preprocess, 671.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 964.2ms
# Speed: 1.5ms preprocess, 964.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 860.1ms
# Speed: 2.6ms preprocess, 860.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 729.3ms
# Speed: 1.8ms preprocess, 729.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 1187.9ms
# Speed: 2.2ms preprocess, 1187.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
